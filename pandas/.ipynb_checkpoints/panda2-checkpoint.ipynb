# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('car-sales.csv')

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# viewing and selecting data

# %%
car.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# loc and iloc

# %%
animals= pd.Series(["cat", "dog","bird", "panda","snake"], index=['a','b','c','d','e'])

# %%
animals
# Out:
# a      cat
# b      dog
# c     bird
# d    panda
# e    snake
# dtype: object

# %%
animals.loc[:'c']
# Out:
# a     cat
# b     dog
# c    bird
# dtype: object

# %%
car.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
#  iloc refers to index position in dataframe

# %%
car.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car[car["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car[car["Odometer (KM)"] > 50000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %% [markdown]
# crosstab is used to compare two columns

# %%
pd.crosstab(car["Make"] , car["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
 #groupby
# car.groupby(["Odometer (KM)"]).mean()
#not working

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
# car["Price"]
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car["Price"]= car["Price"].astype(str)

# %%
# car["Price"] = car["Price"].str.replace("/$/,/.", "").astype(int)

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_missing= pd.read_csv("car-missing.csv")

# %%
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#this method is not preferred rather we should reassign the updated value
# car_missing["Odometer"].fillna(car_missing["Odometer"].mean(), inplace=True) 
#to replace the missing values with the mean value of odometer column

# %%
car_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
#column from series
seats_column= pd.Series([5,5,5,5,5])
#new column called seats in car
car["Seats"]=seats_column
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car["Seats"]=car["Seats"].fillna(4)

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    4.0
# 6   Honda   Blue          45698      4   $7,500.00    4.0
# 7   Honda   Blue          54738      4   $7,000.00    4.0
# 8  Toyota  White          60000      4   $6,250.00    4.0
# 9  Nissan  White          31600      4   $9,700.00    4.0

# %%
fuel_economy=[12,33, 44,34,54,19,25,67,55, 24]
car["Economy"]= fuel_economy

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Economy
# 0  Toyota  White         150043      4   $4,000.00    5.0       12
# 1   Honda    Red          87899      4   $5,000.00    5.0       33
# 2  Toyota   Blue          32549      3   $7,000.00    5.0       44
# 3     BMW  Black          11179      5  $22,000.00    5.0       34
# 4  Nissan  White         213095      4   $3,500.00    5.0       54
# 5  Toyota  Green          99213      4   $4,500.00    4.0       19
# 6   Honda   Blue          45698      4   $7,500.00    4.0       25
# 7   Honda   Blue          54738      4   $7,000.00    4.0       67
# 8  Toyota  White          60000      4   $6,250.00    4.0       55
# 9  Nissan  White          31600      4   $9,700.00    4.0       24

# %%
car["passed road safety"]= True

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Economy  \
# 0  Toyota  White         150043      4   $4,000.00    5.0       12
# 1   Honda    Red          87899      4   $5,000.00    5.0       33
# 2  Toyota   Blue          32549      3   $7,000.00    5.0       44
# 3     BMW  Black          11179      5  $22,000.00    5.0       34
# 4  Nissan  White         213095      4   $3,500.00    5.0       54
# 5  Toyota  Green          99213      4   $4,500.00    4.0       19
# 6   Honda   Blue          45698      4   $7,500.00    4.0       25
# 7   Honda   Blue          54738      4   $7,000.00    4.0       67
# 8  Toyota  White          60000      4   $6,250.00    4.0       55
# 9  Nissan  White          31600      4   $9,700.00    4.0       24
#
#    passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# ...

# %%
car=car.drop(["Seats"], axis=1)

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Economy  \
# 0  Toyota  White         150043      4   $4,000.00       12
# 1   Honda    Red          87899      4   $5,000.00       33
# 2  Toyota   Blue          32549      3   $7,000.00       44
# 3     BMW  Black          11179      5  $22,000.00       34
# 4  Nissan  White         213095      4   $3,500.00       54
# 5  Toyota  Green          99213      4   $4,500.00       19
# 6   Honda   Blue          45698      4   $7,500.00       25
# 7   Honda   Blue          54738      4   $7,000.00       67
# 8  Toyota  White          60000      4   $6,250.00       55
# 9  Nissan  White          31600      4   $9,700.00       24
#
#    passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True

# %%
car_shuffled=car.sample(frac=1)
#to view a sample of the dataframe

# %%
car_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Economy  \
# 0  Toyota  White         150043      4   $4,000.00       12
# 3     BMW  Black          11179      5  $22,000.00       34
# 9  Nissan  White          31600      4   $9,700.00       24
# 1   Honda    Red          87899      4   $5,000.00       33
# 4  Nissan  White         213095      4   $3,500.00       54
# 7   Honda   Blue          54738      4   $7,000.00       67
# 6   Honda   Blue          45698      4   $7,500.00       25
# 2  Toyota   Blue          32549      3   $7,000.00       44
# 8  Toyota  White          60000      4   $6,250.00       55
# 5  Toyota  Green          99213      4   $4,500.00       19
#
#    passed road safety
# 0                True
# 3                True
# 9                True
# 1                True
# 4                True
# 7                True
# 6                True
# 2                True
# 8                True
# 5                True

# %%
car_shuffled.sample(frac=0.30)
#to view only 15% of data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Economy  passed road safety
# 8  Toyota  White          60000      4  $6,250.00       55                True
# 5  Toyota  Green          99213      4  $4,500.00       19                True
# 0  Toyota  White         150043      4  $4,000.00       12                True

# %%
car_shuffled.reset_index(inplace=True, drop=True)
#drop = True is used to not include the index column

# %%
car_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Economy  \
# 0  Toyota  White          60000      4   $6,250.00       55
# 1   Honda   Blue          45698      4   $7,500.00       25
# 2  Nissan  White          31600      4   $9,700.00       24
# 3     BMW  Black          11179      5  $22,000.00       34
# 4  Toyota  White         150043      4   $4,000.00       12
# 5  Toyota  Green          99213      4   $4,500.00       19
# 6   Honda   Blue          54738      4   $7,000.00       67
# 7   Honda    Red          87899      4   $5,000.00       33
# 8  Nissan  White         213095      4   $3,500.00       54
# 9  Toyota   Blue          32549      3   $7,000.00       44
#
#    passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True

# %%
car_shuffled["Odometer(miles)"]= car_shuffled["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Economy  \
# 0  Toyota  White          60000      4   $6,250.00       55
# 1   Honda   Blue          45698      4   $7,500.00       25
# 2  Nissan  White          31600      4   $9,700.00       24
# 3     BMW  Black          11179      5  $22,000.00       34
# 4  Toyota  White         150043      4   $4,000.00       12
# 5  Toyota  Green          99213      4   $4,500.00       19
# 6   Honda   Blue          54738      4   $7,000.00       67
# 7   Honda    Red          87899      4   $5,000.00       33
# 8  Nissan  White         213095      4   $3,500.00       54
# 9  Toyota   Blue          32549      3   $7,000.00       44
#
#    passed road safety  Odometer(miles)
# 0                True        37500.000
# 1                True        28561.250
# 2                True        19750.000
# 3                True         6986.875
# 4                True        93776.875
# 5                True        62008.125
# ...
